# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/sam/Desktop/period.csv')

# %%
df.head()
# Out:
#                 NAME  cycle_number  number_of_peak  Age  Length_of_cycle  \
# 0             Sukrit             1               3   18               27
# 1             Sukrit             2               4   18               25
# 2  Ananya Srivastava             1               2   19               30
# 3       Ananya Gupta             1               3   19               28
# 4               pari             1               2   19               35
#
#    Estimated_day_of_ovulution  Length_of_Leutal_Phase  Length_of_menses  \
# 0                          14                       9                 5
# 1                          17                      10                 6
# 2                          17                      13                 4
# 3                          16                      14                 6
# 4                          18                      15                 5
#
#   Unusual_Bleeding Height  Weight  Income   BMI  Mean_of_length_of_cycle  \
# 0               no    5 6    76.0       0  26.3                       30
# 1              yes    5 6    76.0       0  26.3                       30
# 2               no    5 3    56.0       0  21.9                       30
# 3               no    5 1    61.0       0  25.4                       30
# 4               no    5'3    55.0       0  21.5                       35
#
#    Menses_score
# 0           4.0
# 1           5.0
# 2           2.0
# 3           3.0
# 4           5.0

# %%
df.tail()
# Out:
#              NAME  cycle_number  number_of_peak  Age  Length_of_cycle  \
# 76  Gunjan Manral             2               2   19               35
# 77   Ritika Goyal             2               2   18               30
# 78  Aarti Bafila              2               3   19               40
# 79         maanya             2               2   18               32
# 80          Aisha             2               3   19               28
#
#     Estimated_day_of_ovulution  Length_of_Leutal_Phase  Length_of_menses  \
# 76                          16                      12                 5
# 77                          13                      14                 6
# 78                          16                      14                 6
# 79                          15                      14                 8
# 80                           7                      14                 6
#
#    Unusual_Bleeding Height  Weight  Income   BMI  Mean_of_length_of_cycle  \
# 76               no    5'3    57.0       0  22.3                       30
# 77               no    5'6    64.0       0  22.5                       30
# 78               no    5'3    55.2       0  21.6                       38
# 79               no    5'6    45.5       0  16.2                       32
# 80               no   5'2"    53.0       0  22.0                       28
#
#     Menses_score
# 76           1.0
# 77           2.0
# 78           3.0
# 79           4.0
# 80           5.0

# %%
df.shape
# Out:
# (81, 15)

# %%
df.describe()
# Out:
#        cycle_number  number_of_peak        Age  Length_of_cycle  \
# count     81.000000       81.000000  81.000000        81.000000
# mean       1.308642        2.518519  19.333333        29.283951
# std        0.464811        0.709068   1.457738         4.204862
# min        1.000000        1.000000  14.000000        22.000000
# 25%        1.000000        2.000000  19.000000        27.000000
# 50%        1.000000        2.000000  19.000000        28.000000
# 75%        2.000000        3.000000  20.000000        30.000000
# max        2.000000        5.000000  25.000000        40.000000
#
#        Estimated_day_of_ovulution  Length_of_Leutal_Phase  Length_of_menses  \
# count                   81.000000               81.000000         81.000000
# mean                    15.135802               12.753086          5.061728
# std                      2.359836                3.280743          1.028903
# min                      7.000000                7.000000          1.000000
# 25%                     14.000000               10.000000          5.000000
# 50%                     15.000000               13.000000          5.000000
# 75%                     16.000000               14.000000          6.000000
# max                     22.000000               30.000000          8.000000
#
#           Weight  Income        BMI  Mean_of_length_of_cycle  Menses_score
# count  81.000000    81.0  81.000000                81.000000     81.000000
# mean   56.696296     0.0  21.738889                29.320988      3.372840
# std     9.500993     0.0   2.984680                 5.335792      1.186804
# min    40.000000     0.0  16.200000                13.000000      1.000000
# 25%    51.000000     0.0  20.400000                27.000000      3.000000
# 50%    55.000000     0.0  21.600000                30.000000      3.000000
# 75%    60.000000     0.0  22.500000                30.000000      4.000000
# max    85.000000     0.0  32.900000                46.000000      5.000000

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                  NAME  cycle_number  number_of_peak  Age  Length_of_cycle  \
# 0              Sukrit             1               3   18               27
# 1              Sukrit             2               4   18               25
# 2   Ananya Srivastava             1               2   19               30
# 3        Ananya Gupta             1               3   19               28
# 4                pari             1               2   19               35
# ..                ...           ...             ...  ...              ...
# 76      Gunjan Manral             2               2   19               35
# 77       Ritika Goyal             2               2   18               30
# 78      Aarti Bafila              2               3   19               40
# 79             maanya             2               2   18               32
# 80              Aisha             2               3   19               28
#
#     Estimated_day_of_ovulution  Length_of_Leutal_Phase  Length_of_menses  \
# 0                           14                       9                 5
# 1                           17                      10                 6
# 2                           17                      13                 4
# 3                           16                      14                 6
# 4                           18                      15                 5
# ..                         ...                     ...               ...
# 76                          16                      12                 5
# 77                          13                      14                 6
# 78                          16                      14                 6
# 79                          15                      14                 8
# 80                           7                      14                 6
#
#    Unusual_Bleeding Height  Weight  Income   BMI  Mean_of_length_of_cycle  \
# 0                no    5 6    76.0       0  26.3                       30
# 1               yes    5 6    76.0       0  26.3                       30
# 2                no    5 3    56.0       0  21.9                       30
# 3                no    5 1    61.0       0  25.4                       30
# 4                no    5'3    55.0       0  21.5                       35
# ..              ...    ...     ...     ...   ...                      ...
# 76               no    5'3    57.0       0  22.3                       30
# 77               no    5'6    64.0       0  22.5                       30
# 78               no    5'3    55.2       0  21.6                       38
# 79               no    5'6    45.5       0  16.2                       32
# 80               no   5'2"    53.0       0  22.0                       28
#
#     Menses_score
# 0            4.0
# 1            5.0
# 2            2.0
# 3            3.0
# 4            5.0
# ..           ...
# 76           1.0
# 77           2.0
# 78           3.0
# 79           4.0
# 80           5.0
#
# [81 rows x 15 columns]>

# %%
 from sklearn import linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
df.drop(['Income','NAME'],axis=1)
# Out:
#     cycle_number  number_of_peak  Age  Length_of_cycle  \
# 0              1               3   18               27
# 1              2               4   18               25
# 2              1               2   19               30
# 3              1               3   19               28
# 4              1               2   19               35
# ..           ...             ...  ...              ...
# 76             2               2   19               35
# 77             2               2   18               30
# 78             2               3   19               40
# 79             2               2   18               32
# 80             2               3   19               28
#
#     Estimated_day_of_ovulution  Length_of_Leutal_Phase  Length_of_menses  \
# 0                           14                       9                 5
# 1                           17                      10                 6
# 2                           17                      13                 4
# 3                           16                      14                 6
# 4                           18                      15                 5
# ..                         ...                     ...               ...
# 76                          16                      12                 5
# 77                          13                      14                 6
# 78                          16                      14                 6
# 79                          15                      14                 8
# 80                           7                      14                 6
#
#    Unusual_Bleeding Height  Weight   BMI  Mean_of_length_of_cycle  \
# 0                no    5 6    76.0  26.3                       30
# 1               yes    5 6    76.0  26.3                       30
# 2                no    5 3    56.0  21.9                       30
# 3                no    5 1    61.0  25.4                       30
# 4                no    5'3    55.0  21.5                       35
# ..              ...    ...     ...   ...                      ...
# 76               no    5'3    57.0  22.3                       30
# 77               no    5'6    64.0  22.5                       30
# 78               no    5'3    55.2  21.6                       38
# 79               no    5'6    45.5  16.2                       32
# 80               no   5'2"    53.0  22.0                       28
#
#     Menses_score
# 0            4.0
# 1            5.0
# 2            2.0
# 3            3.0
# 4            5.0
# ..           ...
# 76           1.0
# 77           2.0
# 78           3.0
# 79           4.0
# 80           5.0
#
# [81 rows x 13 columns]

# %%
df.drop(columns=['NAME'])
df.columns
# Out:
# Index(['NAME', 'cycle_number', 'number_of_peak', 'Age', 'Length_of_cycle',
#        'Estimated_day_of_ovulution', 'Length_of_Leutal_Phase',
#        'Length_of_menses', 'Unusual_Bleeding', 'Height', 'Weight', 'Income',
#        'BMI', 'Mean_of_length_of_cycle', 'Menses_score'],
#       dtype='object')

# %%
x=df.drop(columns=['Length_of_cycle','NAME','Unusual_Bleeding','Height'])
x
# Out:
#     cycle_number  number_of_peak  Age  Estimated_day_of_ovulution  \
# 0              1               3   18                          14
# 1              2               4   18                          17
# 2              1               2   19                          17
# 3              1               3   19                          16
# 4              1               2   19                          18
# ..           ...             ...  ...                         ...
# 76             2               2   19                          16
# 77             2               2   18                          13
# 78             2               3   19                          16
# 79             2               2   18                          15
# 80             2               3   19                           7
#
#     Length_of_Leutal_Phase  Length_of_menses  Weight  Income   BMI  \
# 0                        9                 5    76.0       0  26.3
# 1                       10                 6    76.0       0  26.3
# 2                       13                 4    56.0       0  21.9
# 3                       14                 6    61.0       0  25.4
# 4                       15                 5    55.0       0  21.5
# ..                     ...               ...     ...     ...   ...
# 76                      12                 5    57.0       0  22.3
# 77                      14                 6    64.0       0  22.5
# 78                      14                 6    55.2       0  21.6
# 79                      14                 8    45.5       0  16.2
# 80                      14                 6    53.0       0  22.0
#
#     Mean_of_length_of_cycle  Menses_score
# 0                        30           4.0
# 1                        30           5.0
# 2                        30           2.0
# 3                        30           3.0
# 4                        35           5.0
# ..                      ...           ...
# 76                       30           1.0
# 77                       30           2.0
# 78                       38           3.0
# 79                       32           4.0
# 80                       28           5.0
#
# [81 rows x 11 columns]

# %%
y=df['Length_of_cycle']
y
# Out:
# 0     27
# 1     25
# 2     30
# 3     28
# 4     35
#       ..
# 76    35
# 77    30
# 78    40
# 79    32
# 80    28
# Name: Length_of_cycle, Length: 81, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(X_test)

# %%
y_predict
# Out:
# array([32.93610269, 28.93759749, 31.20585795, 25.69943546, 28.76386173,
#        31.19696902, 28.76243237, 30.58647726, 30.79985555, 30.20201903,
#        26.81476282, 34.76627854, 30.72179865, 30.08010613, 29.43958264,
#        34.46778105, 31.89655206, 31.99422688, 30.43560635, 28.34010893,
#        28.37433846, 28.13712785, 31.0098946 , 28.33544321, 25.01139564])

# %%
plt.scatter(y_predict,y_test)

# %%
import pickle
pickle.dump(model,open('lunamodel.pkl','wb'))
